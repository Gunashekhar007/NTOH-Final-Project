# %% [markdown]
# # Japan Tohoku case

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import glob
import os
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# Parameters
NX, NY = 200, 200
zlim = 5.0
input_dir = "wave_data_Japan"
output_file = "Japan_Tohoku.gif"  
frame_step = 3  # Process every 3th frame for smaller files

# Get sorted list of CSV files
frame_files = sorted(glob.glob(os.path.join(input_dir, "frame_*.csv")))
if not frame_files:
    raise FileNotFoundError(f"No CSV files found in {input_dir}")

# Create figure
fig = plt.figure(figsize=(12, 8), dpi=100)  # Reduced DPI for smaller file
ax = fig.add_subplot(111, projection='3d')

# Kilometer-scale coordinates
x_coords = np.linspace(0, (NX-1)*0.5, NX)  # 500m grid -> km units
y_coords = np.linspace(0, (NY-1)*0.5, NY)
X, Y = np.meshgrid(x_coords, y_coords)

def init():
    ax.clear()
    data = pd.read_csv(frame_files[0], header=None).values
    surf = ax.plot_surface(X, Y, data.T, cmap='ocean', vmin=-zlim, vmax=zlim)
    
    ax.set_xlabel('Distance (km)', fontsize=10)
    ax.set_ylabel('Distance (km)', fontsize=10)
    ax.set_zlabel('Wave Height (m)', fontsize=10)
    ax.set_title('2011 Tohoku Tsunami Simulation', fontsize=12)
    ax.set_zlim(-zlim, zlim)
    ax.view_init(elev=40, azim=35)  # Better viewing angle
    
    cbar = fig.colorbar(surf, shrink=0.6)
    cbar.set_label('Wave Height (m)')
    
    return [surf]

def update(frame_num):
    ax.clear()
    data = pd.read_csv(frame_files[frame_num*frame_step], header=None).values
    
    surf = ax.plot_surface(X, Y, data.T, cmap='ocean', 
                         vmin=-zlim, vmax=zlim,
                         rstride=2, cstride=2)  # Reduced density
    
    time_min = (frame_num * frame_step * 0.5) / 60  # Convert to minutes
    ax.set_title(f'Tohoku Tsunami @ {time_min:.1f} min', fontsize=12)
    
    # Maintain consistent styling
    ax.set_xlabel('Distance (km)', fontsize=10)
    ax.set_ylabel('Distance (km)', fontsize=10)
    ax.set_zlabel('Wave Height (m)', fontsize=10)
    ax.set_zlim(-zlim, zlim)
    ax.view_init(elev=40, azim=35)
    
    return [surf]

# Create animation with limited frames
print("Creating optimized animation...")
n_frames = min(500, len(frame_files)//frame_step)  # Max 500 frames
anim = FuncAnimation(fig, update, frames=n_frames,
                    init_func=init, blit=False, interval=100)

# Save with explicit writer settings
writer = 'pillow' if len(frame_files) < 500 else 'imagemagick'
try:
    anim.save(output_file, writer=writer, 
             fps=10, dpi=100, 
             progress_callback=lambda i, n: print(f'Saving frame {i+1}/{n}'))
    print(f"Successfully created {output_file}")
except Exception as e:
    print(f"Error: {str(e)}")
    print("Trying alternative saving method...")
    anim.save(output_file, writer='pillow', fps=8, dpi=80)

plt.close()
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
# Creating optimized animation...
# Saving frame 1/500
# Saving frame 2/500
# Saving frame 3/500
# Saving frame 4/500
# Saving frame 5/500
# Saving frame 6/500
# Saving frame 7/500
# Saving frame 8/500
# Saving frame 9/500
# Saving frame 10/500
# Saving frame 11/500
# Saving frame 12/500
# Saving frame 13/500
# Saving frame 14/500
# Saving frame 15/500
# Saving frame 16/500
# Saving frame 17/500
# Saving frame 18/500
# Saving frame 19/500
# Saving frame 20/500
# Saving frame 21/500
# Saving frame 22/500
# Saving frame 23/500
# Saving frame 24/500
# Saving frame 25/500
# Saving frame 26/500
# Saving frame 27/500
# Saving frame 28/500
# Saving frame 29/500
# Saving frame 30/500
# Saving frame 31/500
# Saving frame 32/500
# Saving frame 33/500
# Saving frame 34/500
# Saving frame 35/500
# Saving frame 36/500
# Saving frame 37/500
# Saving frame 38/500
# Saving frame 39/500
# Saving frame 40/500
# Saving frame 41/500
# Saving frame 42/500
# Saving frame 43/500
# Saving frame 44/500
# Saving frame 45/500
# Saving frame 46/500
# Saving frame 47/500
# Saving frame 48/500
# Saving frame 49/500
# Saving frame 50/500
# Saving frame 51/500
# Saving frame 52/500
# Saving frame 53/500
# Saving frame 54/500
# Saving frame 55/500
# Saving frame 56/500
# Saving frame 57/500
# Saving frame 58/500
# Saving frame 59/500
# Saving frame 60/500
# Saving frame 61/500
# Saving frame 62/500
# Saving frame 63/500
# Saving frame 64/500
# Saving frame 65/500
# Saving frame 66/500
# Saving frame 67/500
# Saving frame 68/500
# Saving frame 69/500
# Saving frame 70/500
# Saving frame 71/500
# Saving frame 72/500
# Saving frame 73/500
# Saving frame 74/500
# Saving frame 75/500
# Saving frame 76/500
# Saving frame 77/500
# Saving frame 78/500
# Saving frame 79/500
# Saving frame 80/500
# Saving frame 81/500
# Saving frame 82/500
# Saving frame 83/500
# Saving frame 84/500
# Saving frame 85/500
# Saving frame 86/500
# Saving frame 87/500
# Saving frame 88/500
# Saving frame 89/500
# Saving frame 90/500
# Saving frame 91/500
# Saving frame 92/500
# Saving frame 93/500
# Saving frame 94/500
# Saving frame 95/500
# Saving frame 96/500
# Saving frame 97/500
# Saving frame 98/500
# Saving frame 99/500
# Saving frame 100/500
# Saving frame 101/500
# Saving frame 102/500
# Saving frame 103/500
# Saving frame 104/500
# Saving frame 105/500
# Saving frame 106/500
# Saving frame 107/500
# Saving frame 108/500
# Saving frame 109/500
# Saving frame 110/500
# Saving frame 111/500
# Saving frame 112/500
# Saving frame 113/500
# Saving frame 114/500
# Saving frame 115/500
# Saving frame 116/500
# Saving frame 117/500
# Saving frame 118/500
# Saving frame 119/500
# Saving frame 120/500
# Saving frame 121/500
# Saving frame 122/500
# Saving frame 123/500
# Saving frame 124/500
# Saving frame 125/500
# Saving frame 126/500
# Saving frame 127/500
# Saving frame 128/500
# Saving frame 129/500
# Saving frame 130/500
# Saving frame 131/500
# Saving frame 132/500
# Saving frame 133/500
# Saving frame 134/500
# Saving frame 135/500
# Saving frame 136/500
# Saving frame 137/500
# Saving frame 138/500
# Saving frame 139/500
# Saving frame 140/500
# Saving frame 141/500
# Saving frame 142/500
# Saving frame 143/500
# Saving frame 144/500
# Saving frame 145/500
# Saving frame 146/500
# Saving frame 147/500
# Saving frame 148/500
# Saving frame 149/500
# Saving frame 150/500
# Saving frame 151/500
# Saving frame 152/500
# Saving frame 153/500
# Saving frame 154/500
# Saving frame 155/500
# Saving frame 156/500
# Saving frame 157/500
# Saving frame 158/500
# Saving frame 159/500
# Saving frame 160/500
# Saving frame 161/500
# Saving frame 162/500
# Saving frame 163/500
# Saving frame 164/500
# Saving frame 165/500
# Saving frame 166/500
# Saving frame 167/500
# Saving frame 168/500
# Saving frame 169/500
# Saving frame 170/500
# Saving frame 171/500
# Saving frame 172/500
# Saving frame 173/500
# Saving frame 174/500
# Saving frame 175/500
# Saving frame 176/500
# Saving frame 177/500
# Saving frame 178/500
# Saving frame 179/500
# Saving frame 180/500
# Saving frame 181/500
# Saving frame 182/500
# Saving frame 183/500
# Saving frame 184/500
# Saving frame 185/500
# Saving frame 186/500
# Saving frame 187/500
# Saving frame 188/500
# Saving frame 189/500
# Saving frame 190/500
# Saving frame 191/500
# Saving frame 192/500
# Saving frame 193/500
# Saving frame 194/500
# Saving frame 195/500
# Saving frame 196/500
# Saving frame 197/500
# Saving frame 198/500
# Saving frame 199/500
# Saving frame 200/500
# Saving frame 201/500
# Saving frame 202/500
# Saving frame 203/500
# Saving frame 204/500
# Saving frame 205/500
# Saving frame 206/500
# Saving frame 207/500
# Saving frame 208/500
# Saving frame 209/500
# Saving frame 210/500
# Saving frame 211/500
# Saving frame 212/500
# Saving frame 213/500
# Saving frame 214/500
# Saving frame 215/500
# Saving frame 216/500
# Saving frame 217/500
# Saving frame 218/500
# Saving frame 219/500
# Saving frame 220/500
# Saving frame 221/500
# Saving frame 222/500
# Saving frame 223/500
# Saving frame 224/500
# Saving frame 225/500
# Saving frame 226/500
# Saving frame 227/500
# Saving frame 228/500
# Saving frame 229/500
# Saving frame 230/500
# Saving frame 231/500
# Saving frame 232/500
# Saving frame 233/500
# Saving frame 234/500
# Saving frame 235/500
# Saving frame 236/500
# Saving frame 237/500
# Saving frame 238/500
# Saving frame 239/500
# Saving frame 240/500
# Saving frame 241/500
# Saving frame 242/500
# Saving frame 243/500
# Saving frame 244/500
# Saving frame 245/500
# Saving frame 246/500
# Saving frame 247/500
# Saving frame 248/500
# Saving frame 249/500
# Saving frame 250/500
# Saving frame 251/500
# Saving frame 252/500
# Saving frame 253/500
# Saving frame 254/500
# Saving frame 255/500
# Saving frame 256/500
# Saving frame 257/500
# Saving frame 258/500
# Saving frame 259/500
# Saving frame 260/500
# Saving frame 261/500
# Saving frame 262/500
# Saving frame 263/500
# Saving frame 264/500
# Saving frame 265/500
# Saving frame 266/500
# Saving frame 267/500
# Saving frame 268/500
# Saving frame 269/500
# Saving frame 270/500
# Saving frame 271/500
# Saving frame 272/500
# Saving frame 273/500
# Saving frame 274/500
# Saving frame 275/500
# Saving frame 276/500
# Saving frame 277/500
# Saving frame 278/500
# Saving frame 279/500
# Saving frame 280/500
# Saving frame 281/500
# Saving frame 282/500
# Saving frame 283/500
# Saving frame 284/500
# Saving frame 285/500
# Saving frame 286/500
# Saving frame 287/500
# Saving frame 288/500
# Saving frame 289/500
# Saving frame 290/500
# Saving frame 291/500
# Saving frame 292/500
# Saving frame 293/500
# Saving frame 294/500
# Saving frame 295/500
# Saving frame 296/500
# Saving frame 297/500
# Saving frame 298/500
# Saving frame 299/500
# Saving frame 300/500
# Saving frame 301/500
# Saving frame 302/500
# Saving frame 303/500
# Saving frame 304/500
# Saving frame 305/500
# Saving frame 306/500
# Saving frame 307/500
# Saving frame 308/500
# Saving frame 309/500
# Saving frame 310/500
# Saving frame 311/500
# Saving frame 312/500
# Saving frame 313/500
# Saving frame 314/500
# Saving frame 315/500
# Saving frame 316/500
# Saving frame 317/500
# Saving frame 318/500
# Saving frame 319/500
# Saving frame 320/500
# Saving frame 321/500
# Saving frame 322/500
# Saving frame 323/500
# Saving frame 324/500
# Saving frame 325/500
# Saving frame 326/500
# Saving frame 327/500
# Saving frame 328/500
# Saving frame 329/500
# Saving frame 330/500
# Saving frame 331/500
# Saving frame 332/500
# Saving frame 333/500
# Saving frame 334/500
# Saving frame 335/500
# Saving frame 336/500
# Saving frame 337/500
# Saving frame 338/500
# Saving frame 339/500
# Saving frame 340/500
# Saving frame 341/500
# Saving frame 342/500
# Saving frame 343/500
# Saving frame 344/500
# Saving frame 345/500
# Saving frame 346/500
# Saving frame 347/500
# Saving frame 348/500
# Saving frame 349/500
# Saving frame 350/500
# Saving frame 351/500
# Saving frame 352/500
# Saving frame 353/500
# Saving frame 354/500
# Saving frame 355/500
# Saving frame 356/500
# Saving frame 357/500
# Saving frame 358/500
# Saving frame 359/500
# Saving frame 360/500
# Saving frame 361/500
# Saving frame 362/500
# Saving frame 363/500
# Saving frame 364/500
# Saving frame 365/500
# Saving frame 366/500
# Saving frame 367/500
# Saving frame 368/500
# Saving frame 369/500
# Saving frame 370/500
# Saving frame 371/500
# Saving frame 372/500
# Saving frame 373/500
# Saving frame 374/500
# Saving frame 375/500
# Saving frame 376/500
# Saving frame 377/500
# Saving frame 378/500
# Saving frame 379/500
# Saving frame 380/500
# Saving frame 381/500
# Saving frame 382/500
# Saving frame 383/500
# Saving frame 384/500
# Saving frame 385/500
# Saving frame 386/500
# Saving frame 387/500
# Saving frame 388/500
# Saving frame 389/500
# Saving frame 390/500
# Saving frame 391/500
# Saving frame 392/500
# Saving frame 393/500
# Saving frame 394/500
# Saving frame 395/500
# Saving frame 396/500
# Saving frame 397/500
# Saving frame 398/500
# Saving frame 399/500
# Saving frame 400/500
# Saving frame 401/500
# Saving frame 402/500
# Saving frame 403/500
# Saving frame 404/500
# Saving frame 405/500
# Saving frame 406/500
# Saving frame 407/500
# Saving frame 408/500
# Saving frame 409/500
# Saving frame 410/500
# Saving frame 411/500
# Saving frame 412/500
# Saving frame 413/500
# Saving frame 414/500
# Saving frame 415/500
# Saving frame 416/500
# Saving frame 417/500
# Saving frame 418/500
# Saving frame 419/500
# Saving frame 420/500
# Saving frame 421/500
# Saving frame 422/500
# Saving frame 423/500
# Saving frame 424/500
# Saving frame 425/500
# Saving frame 426/500
# Saving frame 427/500
# Saving frame 428/500
# Saving frame 429/500
# Saving frame 430/500
# Saving frame 431/500
# Saving frame 432/500
# Saving frame 433/500
# Saving frame 434/500
# Saving frame 435/500
# Saving frame 436/500
# Saving frame 437/500
# Saving frame 438/500
# Saving frame 439/500
# Saving frame 440/500
# Saving frame 441/500
# Saving frame 442/500
# Saving frame 443/500
# Saving frame 444/500
# Saving frame 445/500
# Saving frame 446/500
# Saving frame 447/500
# Saving frame 448/500
# Saving frame 449/500
# Saving frame 450/500
# Saving frame 451/500
# Saving frame 452/500
# Saving frame 453/500
# Saving frame 454/500
# Saving frame 455/500
# Saving frame 456/500
# Saving frame 457/500
# Saving frame 458/500
# Saving frame 459/500
# Saving frame 460/500
# Saving frame 461/500
# Saving frame 462/500
# Saving frame 463/500
# Saving frame 464/500
# Saving frame 465/500
# Saving frame 466/500
# Saving frame 467/500
# Saving frame 468/500
# Saving frame 469/500
# Saving frame 470/500
# Saving frame 471/500
# Saving frame 472/500
# Saving frame 473/500
# Saving frame 474/500
# Saving frame 475/500
# Saving frame 476/500
# Saving frame 477/500
# Saving frame 478/500
# Saving frame 479/500
# Saving frame 480/500
# Saving frame 481/500
# Saving frame 482/500
# Saving frame 483/500
# Saving frame 484/500
# Saving frame 485/500
# Saving frame 486/500
# Saving frame 487/500
# Saving frame 488/500
# Saving frame 489/500
# Saving frame 490/500
# Saving frame 491/500
# Saving frame 492/500
# Saving frame 493/500
# Saving frame 494/500
# Saving frame 495/500
# Saving frame 496/500
# Saving frame 497/500
# Saving frame 498/500
# Saving frame 499/500
# Saving frame 500/500
# Successfully created Japan_Tohoku.gif

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import glob
import os
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# Parameters
NX, NY = 200, 200
zlim = 5.0
input_dir = "wave_data_Japan"
output_file = "Japan_Tohoku_seismic.gif"  
frame_step = 3  # Process every 3th frame for smaller files

# Get sorted list of CSV files
frame_files = sorted(glob.glob(os.path.join(input_dir, "frame_*.csv")))
if not frame_files:
    raise FileNotFoundError(f"No CSV files found in {input_dir}")

# Create figure
fig = plt.figure(figsize=(12, 8), dpi=100)  # Reduced DPI for smaller file
ax = fig.add_subplot(111, projection='3d')

# Kilometer-scale coordinates
x_coords = np.linspace(0, (NX-1)*0.5, NX)  # 500m grid -> km units
y_coords = np.linspace(0, (NY-1)*0.5, NY)
X, Y = np.meshgrid(x_coords, y_coords)

def init():
    ax.clear()
    data = pd.read_csv(frame_files[0], header=None).values
    surf = ax.plot_surface(X, Y, data.T, cmap='seismic', vmin=-zlim, vmax=zlim)
    
    ax.set_xlabel('Distance (km)', fontsize=10)
    ax.set_ylabel('Distance (km)', fontsize=10)
    ax.set_zlabel('Wave Height (m)', fontsize=10)
    ax.set_title('2011 Tohoku Tsunami Simulation', fontsize=12)
    ax.set_zlim(-zlim, zlim)
    ax.view_init(elev=40, azim=35)  # Better viewing angle
    
    cbar = fig.colorbar(surf, shrink=0.6)
    cbar.set_label('Wave Height (m)')
    
    return [surf]

def update(frame_num):
    ax.clear()
    data = pd.read_csv(frame_files[frame_num*frame_step], header=None).values
    
    surf = ax.plot_surface(X, Y, data.T, cmap='seismic', 
                         vmin=-zlim, vmax=zlim,
                         rstride=2, cstride=2)  # Reduced density
    
    time_min = (frame_num * frame_step * 0.5) / 60  # Convert to minutes
    ax.set_title(f'Tohoku Tsunami @ {time_min:.1f} min', fontsize=12)
    
    # Maintain consistent styling
    ax.set_xlabel('Distance (km)', fontsize=10)
    ax.set_ylabel('Distance (km)', fontsize=10)
    ax.set_zlabel('Wave Height (m)', fontsize=10)
    ax.set_zlim(-zlim, zlim)
    ax.view_init(elev=40, azim=35)
    
    return [surf]

# Create animation with limited frames
print("Creating optimized animation...")
n_frames = min(500, len(frame_files)//frame_step)  # Max 500 frames
anim = FuncAnimation(fig, update, frames=n_frames,
                    init_func=init, blit=False, interval=100)

# Save with explicit writer settings
writer = 'pillow' if len(frame_files) < 500 else 'imagemagick'
try:
    anim.save(output_file, writer=writer, 
             fps=10, dpi=100, 
             progress_callback=lambda i, n: print(f'Saving frame {i+1}/{n}'))
    print(f"Successfully created {output_file}")
except Exception as e:
    print(f"Error: {str(e)}")
    print("Trying alternative saving method...")
    anim.save(output_file, writer='pillow', fps=8, dpi=80)

plt.close()
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
# Creating optimized animation...
# Saving frame 1/500
# Saving frame 2/500
# Saving frame 3/500
# Saving frame 4/500
# Saving frame 5/500
# Saving frame 6/500
# Saving frame 7/500
# Saving frame 8/500
# Saving frame 9/500
# Saving frame 10/500
# Saving frame 11/500
# Saving frame 12/500
# Saving frame 13/500
# Saving frame 14/500
# Saving frame 15/500
# Saving frame 16/500
# Saving frame 17/500
# Saving frame 18/500
# Saving frame 19/500
# Saving frame 20/500
# Saving frame 21/500
# Saving frame 22/500
# Saving frame 23/500
# Saving frame 24/500
# Saving frame 25/500
# Saving frame 26/500
# Saving frame 27/500
# Saving frame 28/500
# Saving frame 29/500
# Saving frame 30/500
# Saving frame 31/500
# Saving frame 32/500
# Saving frame 33/500
# Saving frame 34/500
# Saving frame 35/500
# Saving frame 36/500
# Saving frame 37/500
# Saving frame 38/500
# Saving frame 39/500
# Saving frame 40/500
# Saving frame 41/500
# Saving frame 42/500
# Saving frame 43/500
# Saving frame 44/500
# Saving frame 45/500
# Saving frame 46/500
# Saving frame 47/500
# Saving frame 48/500
# Saving frame 49/500
# Saving frame 50/500
# Saving frame 51/500
# Saving frame 52/500
# Saving frame 53/500
# Saving frame 54/500
# Saving frame 55/500
# Saving frame 56/500
# Saving frame 57/500
# Saving frame 58/500
# Saving frame 59/500
# Saving frame 60/500
# Saving frame 61/500
# Saving frame 62/500
# Saving frame 63/500
# Saving frame 64/500
# Saving frame 65/500
# Saving frame 66/500
# Saving frame 67/500
# Saving frame 68/500
# Saving frame 69/500
# Saving frame 70/500
# Saving frame 71/500
# Saving frame 72/500
# Saving frame 73/500
# Saving frame 74/500
# Saving frame 75/500
# Saving frame 76/500
# Saving frame 77/500
# Saving frame 78/500
# Saving frame 79/500
# Saving frame 80/500
# Saving frame 81/500
# Saving frame 82/500
# Saving frame 83/500
# Saving frame 84/500
# Saving frame 85/500
# Saving frame 86/500
# Saving frame 87/500
# Saving frame 88/500
# Saving frame 89/500
# Saving frame 90/500
# Saving frame 91/500
# Saving frame 92/500
# Saving frame 93/500
# Saving frame 94/500
# Saving frame 95/500
# Saving frame 96/500
# Saving frame 97/500
# Saving frame 98/500
# Saving frame 99/500
# Saving frame 100/500
# Saving frame 101/500
# Saving frame 102/500
# Saving frame 103/500
# Saving frame 104/500
# Saving frame 105/500
# Saving frame 106/500
# Saving frame 107/500
# Saving frame 108/500
# Saving frame 109/500
# Saving frame 110/500
# Saving frame 111/500
# Saving frame 112/500
# Saving frame 113/500
# Saving frame 114/500
# Saving frame 115/500
# Saving frame 116/500
# Saving frame 117/500
# Saving frame 118/500
# Saving frame 119/500
# Saving frame 120/500
# Saving frame 121/500
# Saving frame 122/500
# Saving frame 123/500
# Saving frame 124/500
# Saving frame 125/500
# Saving frame 126/500
# Saving frame 127/500
# Saving frame 128/500
# Saving frame 129/500
# Saving frame 130/500
# Saving frame 131/500
# Saving frame 132/500
# Saving frame 133/500
# Saving frame 134/500
# Saving frame 135/500
# Saving frame 136/500
# Saving frame 137/500
# Saving frame 138/500
# Saving frame 139/500
# Saving frame 140/500
# Saving frame 141/500
# Saving frame 142/500
# Saving frame 143/500
# Saving frame 144/500
# Saving frame 145/500
# Saving frame 146/500
# Saving frame 147/500
# Saving frame 148/500
# Saving frame 149/500
# Saving frame 150/500
# Saving frame 151/500
# Saving frame 152/500
# Saving frame 153/500
# Saving frame 154/500
# Saving frame 155/500
# Saving frame 156/500
# Saving frame 157/500
# Saving frame 158/500
# Saving frame 159/500
# Saving frame 160/500
# Saving frame 161/500
# Saving frame 162/500
# Saving frame 163/500
# Saving frame 164/500
# Saving frame 165/500
# Saving frame 166/500
# Saving frame 167/500
# Saving frame 168/500
# Saving frame 169/500
# Saving frame 170/500
# Saving frame 171/500
# Saving frame 172/500
# Saving frame 173/500
# Saving frame 174/500
# Saving frame 175/500
# Saving frame 176/500
# Saving frame 177/500
# Saving frame 178/500
# Saving frame 179/500
# Saving frame 180/500
# Saving frame 181/500
# Saving frame 182/500
# Saving frame 183/500
# Saving frame 184/500
# Saving frame 185/500
# Saving frame 186/500
# Saving frame 187/500
# Saving frame 188/500
# Saving frame 189/500
# Saving frame 190/500
# Saving frame 191/500
# Saving frame 192/500
# Saving frame 193/500
# Saving frame 194/500
# Saving frame 195/500
# Saving frame 196/500
# Saving frame 197/500
# Saving frame 198/500
# Saving frame 199/500
# Saving frame 200/500
# Saving frame 201/500
# Saving frame 202/500
# Saving frame 203/500
# Saving frame 204/500
# Saving frame 205/500
# Saving frame 206/500
# Saving frame 207/500
# Saving frame 208/500
# Saving frame 209/500
# Saving frame 210/500
# Saving frame 211/500
# Saving frame 212/500
# Saving frame 213/500
# Saving frame 214/500
# Saving frame 215/500
# Saving frame 216/500
# Saving frame 217/500
# Saving frame 218/500
# Saving frame 219/500
# Saving frame 220/500
# Saving frame 221/500
# Saving frame 222/500
# Saving frame 223/500
# Saving frame 224/500
# Saving frame 225/500
# Saving frame 226/500
# Saving frame 227/500
# Saving frame 228/500
# Saving frame 229/500
# Saving frame 230/500
# Saving frame 231/500
# Saving frame 232/500
# Saving frame 233/500
# Saving frame 234/500
# Saving frame 235/500
# Saving frame 236/500
# Saving frame 237/500
# Saving frame 238/500
# Saving frame 239/500
# Saving frame 240/500
# Saving frame 241/500
# Saving frame 242/500
# Saving frame 243/500
# Saving frame 244/500
# Saving frame 245/500
# Saving frame 246/500
# Saving frame 247/500
# Saving frame 248/500
# Saving frame 249/500
# Saving frame 250/500
# Saving frame 251/500
# Saving frame 252/500
# Saving frame 253/500
# Saving frame 254/500
# Saving frame 255/500
# Saving frame 256/500
# Saving frame 257/500
# Saving frame 258/500
# Saving frame 259/500
# Saving frame 260/500
# Saving frame 261/500
# Saving frame 262/500
# Saving frame 263/500
# Saving frame 264/500
# Saving frame 265/500
# Saving frame 266/500
# Saving frame 267/500
# Saving frame 268/500
# Saving frame 269/500
# Saving frame 270/500
# Saving frame 271/500
# Saving frame 272/500
# Saving frame 273/500
# Saving frame 274/500
# Saving frame 275/500
# Saving frame 276/500
# Saving frame 277/500
# Saving frame 278/500
# Saving frame 279/500
# Saving frame 280/500
# Saving frame 281/500
# Saving frame 282/500
# Saving frame 283/500
# Saving frame 284/500
# Saving frame 285/500
# Saving frame 286/500
# Saving frame 287/500
# Saving frame 288/500
# Saving frame 289/500
# Saving frame 290/500
# Saving frame 291/500
# Saving frame 292/500
# Saving frame 293/500
# Saving frame 294/500
# Saving frame 295/500
# Saving frame 296/500
# Saving frame 297/500
# Saving frame 298/500
# Saving frame 299/500
# Saving frame 300/500
# Saving frame 301/500
# Saving frame 302/500
# Saving frame 303/500
# Saving frame 304/500
# Saving frame 305/500
# Saving frame 306/500
# Saving frame 307/500
# Saving frame 308/500
# Saving frame 309/500
# Saving frame 310/500
# Saving frame 311/500
# Saving frame 312/500
# Saving frame 313/500
# Saving frame 314/500
# Saving frame 315/500
# Saving frame 316/500
# Saving frame 317/500
# Saving frame 318/500
# Saving frame 319/500
# Saving frame 320/500
# Saving frame 321/500
# Saving frame 322/500
# Saving frame 323/500
# Saving frame 324/500
# Saving frame 325/500
# Saving frame 326/500
# Saving frame 327/500
# Saving frame 328/500
# Saving frame 329/500
# Saving frame 330/500
# Saving frame 331/500
# Saving frame 332/500
# Saving frame 333/500
# Saving frame 334/500
# Saving frame 335/500
# Saving frame 336/500
# Saving frame 337/500
# Saving frame 338/500
# Saving frame 339/500
# Saving frame 340/500
# Saving frame 341/500
# Saving frame 342/500
# Saving frame 343/500
# Saving frame 344/500
# Saving frame 345/500
# Saving frame 346/500
# Saving frame 347/500
# Saving frame 348/500
# Saving frame 349/500
# Saving frame 350/500
# Saving frame 351/500
# Saving frame 352/500
# Saving frame 353/500
# Saving frame 354/500
# Saving frame 355/500
# Saving frame 356/500
# Saving frame 357/500
# Saving frame 358/500
# Saving frame 359/500
# Saving frame 360/500
# Saving frame 361/500
# Saving frame 362/500
# Saving frame 363/500
# Saving frame 364/500
# Saving frame 365/500
# Saving frame 366/500
# Saving frame 367/500
# Saving frame 368/500
# Saving frame 369/500
# Saving frame 370/500
# Saving frame 371/500
# Saving frame 372/500
# Saving frame 373/500
# Saving frame 374/500
# Saving frame 375/500
# Saving frame 376/500
# Saving frame 377/500
# Saving frame 378/500
# Saving frame 379/500
# Saving frame 380/500
# Saving frame 381/500
# Saving frame 382/500
# Saving frame 383/500
# Saving frame 384/500
# Saving frame 385/500
# Saving frame 386/500
# Saving frame 387/500
# Saving frame 388/500
# Saving frame 389/500
# Saving frame 390/500
# Saving frame 391/500
# Saving frame 392/500
# Saving frame 393/500
# Saving frame 394/500
# Saving frame 395/500
# Saving frame 396/500
# Saving frame 397/500
# Saving frame 398/500
# Saving frame 399/500
# Saving frame 400/500
# Saving frame 401/500
# Saving frame 402/500
# Saving frame 403/500
# Saving frame 404/500
# Saving frame 405/500
# Saving frame 406/500
# Saving frame 407/500
# Saving frame 408/500
# Saving frame 409/500
# Saving frame 410/500
# Saving frame 411/500
# Saving frame 412/500
# Saving frame 413/500
# Saving frame 414/500
# Saving frame 415/500
# Saving frame 416/500
# Saving frame 417/500
# Saving frame 418/500
# Saving frame 419/500
# Saving frame 420/500
# Saving frame 421/500
# Saving frame 422/500
# Saving frame 423/500
# Saving frame 424/500
# Saving frame 425/500
# Saving frame 426/500
# Saving frame 427/500
# Saving frame 428/500
# Saving frame 429/500
# Saving frame 430/500
# Saving frame 431/500
# Saving frame 432/500
# Saving frame 433/500
# Saving frame 434/500
# Saving frame 435/500
# Saving frame 436/500
# Saving frame 437/500
# Saving frame 438/500
# Saving frame 439/500
# Saving frame 440/500
# Saving frame 441/500
# Saving frame 442/500
# Saving frame 443/500
# Saving frame 444/500
# Saving frame 445/500
# Saving frame 446/500
# Saving frame 447/500
# Saving frame 448/500
# Saving frame 449/500
# Saving frame 450/500
# Saving frame 451/500
# Saving frame 452/500
# Saving frame 453/500
# Saving frame 454/500
# Saving frame 455/500
# Saving frame 456/500
# Saving frame 457/500
# Saving frame 458/500
# Saving frame 459/500
# Saving frame 460/500
# Saving frame 461/500
# Saving frame 462/500
# Saving frame 463/500
# Saving frame 464/500
# Saving frame 465/500
# Saving frame 466/500
# Saving frame 467/500
# Saving frame 468/500
# Saving frame 469/500
# Saving frame 470/500
# Saving frame 471/500
# Saving frame 472/500
# Saving frame 473/500
# Saving frame 474/500
# Saving frame 475/500
# Saving frame 476/500
# Saving frame 477/500
# Saving frame 478/500
# Saving frame 479/500
# Saving frame 480/500
# Saving frame 481/500
# Saving frame 482/500
# Saving frame 483/500
# Saving frame 484/500
# Saving frame 485/500
# Saving frame 486/500
# Saving frame 487/500
# Saving frame 488/500
# Saving frame 489/500
# Saving frame 490/500
# Saving frame 491/500
# Saving frame 492/500
# Saving frame 493/500
# Saving frame 494/500
# Saving frame 495/500
# Saving frame 496/500
# Saving frame 497/500
# Saving frame 498/500
# Saving frame 499/500
# Saving frame 500/500
# Successfully created Japan_Tohoku_seismic.gif

# %% [markdown]
# # 2004 Indian Ocean Tsunami

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import glob
import os
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# Parameters
NX, NY = 200, 200
zlim = 10.0
input_dir = "wave_data_india"
output_file = "2004_Indian_ocean.gif"  
frame_step = 3  # Process every 3th frame for smaller files

# Get sorted list of CSV files
frame_files = sorted(glob.glob(os.path.join(input_dir, "frame_*.csv")))
if not frame_files:
    raise FileNotFoundError(f"No CSV files found in {input_dir}")

# Create figure
fig = plt.figure(figsize=(12, 8), dpi=100)  # Reduced DPI for smaller file
ax = fig.add_subplot(111, projection='3d')

# Kilometer-scale coordinates
x_coords = np.linspace(0, (NX-1)*0.5, NX)  # 500m grid -> km units
y_coords = np.linspace(0, (NY-1)*0.5, NY)
X, Y = np.meshgrid(x_coords, y_coords)

def init():
    ax.clear()
    data = pd.read_csv(frame_files[0], header=None).values
    surf = ax.plot_surface(X, Y, data.T, cmap='ocean', vmin=-zlim, vmax=zlim)
    
    ax.set_xlabel('Distance (km)', fontsize=10)
    ax.set_ylabel('Distance (km)', fontsize=10)
    ax.set_zlabel('Wave Height (m)', fontsize=10)
    ax.set_title('2004 Indian Ocean Tsunami\nSimulation', fontsize=12)
    ax.set_zlim(-zlim, zlim)
    ax.view_init(elev=40, azim=35)  # Better viewing angle
    
    cbar = fig.colorbar(surf, shrink=0.6)
    cbar.set_label('Wave Height (m)')
    
    return [surf]

def update(frame_num):
    ax.clear()
    data = pd.read_csv(frame_files[frame_num*frame_step], header=None).values
    
    surf = ax.plot_surface(X, Y, data.T, cmap='ocean', 
                         vmin=-zlim, vmax=zlim,
                         rstride=2, cstride=2)  # Reduced density
    
    time_min = (frame_num * frame_step * 0.5) / 60  # Convert to minutes
    ax.set_title(f'Indian Ocean Tsunami @ {time_min:.1f} min', fontsize=12)
    
    # Maintain consistent styling
    ax.set_xlabel('Distance (km)', fontsize=10)
    ax.set_ylabel('Distance (km)', fontsize=10)
    ax.set_zlabel('Wave Height (m)', fontsize=10)
    ax.set_zlim(-zlim, zlim)
    ax.view_init(elev=40, azim=35)
    
    return [surf]

# Create animation with limited frames
print("Creating optimized animation...")
n_frames = min(500, len(frame_files)//frame_step)  # Max 500 frames
anim = FuncAnimation(fig, update, frames=n_frames,
                    init_func=init, blit=False, interval=100)

# Save with explicit writer settings
writer = 'pillow' if len(frame_files) < 500 else 'imagemagick'
try:
    anim.save(output_file, writer=writer, 
             fps=10, dpi=100, 
             progress_callback=lambda i, n: print(f'Saving frame {i+1}/{n}'))
    print(f"Successfully created {output_file}")
except Exception as e:
    print(f"Error: {str(e)}")
    print("Trying alternative saving method...")
    anim.save(output_file, writer='pillow', fps=8, dpi=80)

plt.close()
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
# Creating optimized animation...
# Saving frame 1/500
# Saving frame 2/500
# Saving frame 3/500
# Saving frame 4/500
# Saving frame 5/500
# Saving frame 6/500
# Saving frame 7/500
# Saving frame 8/500
# Saving frame 9/500
# Saving frame 10/500
# Saving frame 11/500
# Saving frame 12/500
# Saving frame 13/500
# Saving frame 14/500
# Saving frame 15/500
# Saving frame 16/500
# Saving frame 17/500
# Saving frame 18/500
# Saving frame 19/500
# Saving frame 20/500
# Saving frame 21/500
# Saving frame 22/500
# Saving frame 23/500
# Saving frame 24/500
# Saving frame 25/500
# Saving frame 26/500
# Saving frame 27/500
# Saving frame 28/500
# Saving frame 29/500
# Saving frame 30/500
# Saving frame 31/500
# Saving frame 32/500
# Saving frame 33/500
# Saving frame 34/500
# Saving frame 35/500
# Saving frame 36/500
# Saving frame 37/500
# Saving frame 38/500
# Saving frame 39/500
# Saving frame 40/500
# Saving frame 41/500
# Saving frame 42/500
# Saving frame 43/500
# Saving frame 44/500
# Saving frame 45/500
# Saving frame 46/500
# Saving frame 47/500
# Saving frame 48/500
# Saving frame 49/500
# Saving frame 50/500
# Saving frame 51/500
# Saving frame 52/500
# Saving frame 53/500
# Saving frame 54/500
# Saving frame 55/500
# Saving frame 56/500
# Saving frame 57/500
# Saving frame 58/500
# Saving frame 59/500
# Saving frame 60/500
# Saving frame 61/500
# Saving frame 62/500
# Saving frame 63/500
# Saving frame 64/500
# Saving frame 65/500
# Saving frame 66/500
# Saving frame 67/500
# Saving frame 68/500
# Saving frame 69/500
# Saving frame 70/500
# Saving frame 71/500
# Saving frame 72/500
# Saving frame 73/500
# Saving frame 74/500
# Saving frame 75/500
# Saving frame 76/500
# Saving frame 77/500
# Saving frame 78/500
# Saving frame 79/500
# Saving frame 80/500
# Saving frame 81/500
# Saving frame 82/500
# Saving frame 83/500
# Saving frame 84/500
# Saving frame 85/500
# Saving frame 86/500
# Saving frame 87/500
# Saving frame 88/500
# Saving frame 89/500
# Saving frame 90/500
# Saving frame 91/500
# Saving frame 92/500
# Saving frame 93/500
# Saving frame 94/500
# Saving frame 95/500
# Saving frame 96/500
# Saving frame 97/500
# Saving frame 98/500
# Saving frame 99/500
# Saving frame 100/500
# Saving frame 101/500
# Saving frame 102/500
# Saving frame 103/500
# Saving frame 104/500
# Saving frame 105/500
# Saving frame 106/500
# Saving frame 107/500
# Saving frame 108/500
# Saving frame 109/500
# Saving frame 110/500
# Saving frame 111/500
# Saving frame 112/500
# Saving frame 113/500
# Saving frame 114/500
# Saving frame 115/500
# Saving frame 116/500
# Saving frame 117/500
# Saving frame 118/500
# Saving frame 119/500
# Saving frame 120/500
# Saving frame 121/500
# Saving frame 122/500
# Saving frame 123/500
# Saving frame 124/500
# Saving frame 125/500
# Saving frame 126/500
# Saving frame 127/500
# Saving frame 128/500
# Saving frame 129/500
# Saving frame 130/500
# Saving frame 131/500
# Saving frame 132/500
# Saving frame 133/500
# Saving frame 134/500
# Saving frame 135/500
# Saving frame 136/500
# Saving frame 137/500
# Saving frame 138/500
# Saving frame 139/500
# Saving frame 140/500
# Saving frame 141/500
# Saving frame 142/500
# Saving frame 143/500
# Saving frame 144/500
# Saving frame 145/500
# Saving frame 146/500
# Saving frame 147/500
# Saving frame 148/500
# Saving frame 149/500
# Saving frame 150/500
# Saving frame 151/500
# Saving frame 152/500
# Saving frame 153/500
# Saving frame 154/500
# Saving frame 155/500
# Saving frame 156/500
# Saving frame 157/500
# Saving frame 158/500
# Saving frame 159/500
# Saving frame 160/500
# Saving frame 161/500
# Saving frame 162/500
# Saving frame 163/500
# Saving frame 164/500
# Saving frame 165/500
# Saving frame 166/500
# Saving frame 167/500
# Saving frame 168/500
# Saving frame 169/500
# Saving frame 170/500
# Saving frame 171/500
# Saving frame 172/500
# Saving frame 173/500
# Saving frame 174/500
# Saving frame 175/500
# Saving frame 176/500
# Saving frame 177/500
# Saving frame 178/500
# Saving frame 179/500
# Saving frame 180/500
# Saving frame 181/500
# Saving frame 182/500
# Saving frame 183/500
# Saving frame 184/500
# Saving frame 185/500
# Saving frame 186/500
# Saving frame 187/500
# Saving frame 188/500
# Saving frame 189/500
# Saving frame 190/500
# Saving frame 191/500
# Saving frame 192/500
# Saving frame 193/500
# Saving frame 194/500
# Saving frame 195/500
# Saving frame 196/500
# Saving frame 197/500
# Saving frame 198/500
# Saving frame 199/500
# Saving frame 200/500
# Saving frame 201/500
# Saving frame 202/500
# Saving frame 203/500
# Saving frame 204/500
# Saving frame 205/500
# Saving frame 206/500
# Saving frame 207/500
# Saving frame 208/500
# Saving frame 209/500
# Saving frame 210/500
# Saving frame 211/500
# Saving frame 212/500
# Saving frame 213/500
# Saving frame 214/500
# Saving frame 215/500
# Saving frame 216/500
# Saving frame 217/500
# Saving frame 218/500
# Saving frame 219/500
# Saving frame 220/500
# Saving frame 221/500
# Saving frame 222/500
# Saving frame 223/500
# Saving frame 224/500
# Saving frame 225/500
# Saving frame 226/500
# Saving frame 227/500
# Saving frame 228/500
# Saving frame 229/500
# Saving frame 230/500
# Saving frame 231/500
# Saving frame 232/500
# Saving frame 233/500
# Saving frame 234/500
# Saving frame 235/500
# Saving frame 236/500
# Saving frame 237/500
# Saving frame 238/500
# Saving frame 239/500
# Saving frame 240/500
# Saving frame 241/500
# Saving frame 242/500
# Saving frame 243/500
# Saving frame 244/500
# Saving frame 245/500
# Saving frame 246/500
# Saving frame 247/500
# Saving frame 248/500
# Saving frame 249/500
# Saving frame 250/500
# Saving frame 251/500
# Saving frame 252/500
# Saving frame 253/500
# Saving frame 254/500
# Saving frame 255/500
# Saving frame 256/500
# Saving frame 257/500
# Saving frame 258/500
# Saving frame 259/500
# Saving frame 260/500
# Saving frame 261/500
# Saving frame 262/500
# Saving frame 263/500
# Saving frame 264/500
# Saving frame 265/500
# Saving frame 266/500
# Saving frame 267/500
# Saving frame 268/500
# Saving frame 269/500
# Saving frame 270/500
# Saving frame 271/500
# Saving frame 272/500
# Saving frame 273/500
# Saving frame 274/500
# Saving frame 275/500
# Saving frame 276/500
# Saving frame 277/500
# Saving frame 278/500
# Saving frame 279/500
# Saving frame 280/500
# Saving frame 281/500
# Saving frame 282/500
# Saving frame 283/500
# Saving frame 284/500
# Saving frame 285/500
# Saving frame 286/500
# Saving frame 287/500
# Saving frame 288/500
# Saving frame 289/500
# Saving frame 290/500
# Saving frame 291/500
# Saving frame 292/500
# Saving frame 293/500
# Saving frame 294/500
# Saving frame 295/500
# Saving frame 296/500
# Saving frame 297/500
# Saving frame 298/500
# Saving frame 299/500
# Saving frame 300/500
# Saving frame 301/500
# Saving frame 302/500
# Saving frame 303/500
# Saving frame 304/500
# Saving frame 305/500
# Saving frame 306/500
# Saving frame 307/500
# Saving frame 308/500
# Saving frame 309/500
# Saving frame 310/500
# Saving frame 311/500
# Saving frame 312/500
# Saving frame 313/500
# Saving frame 314/500
# Saving frame 315/500
# Saving frame 316/500
# Saving frame 317/500
# Saving frame 318/500
# Saving frame 319/500
# Saving frame 320/500
# Saving frame 321/500
# Saving frame 322/500
# Saving frame 323/500
# Saving frame 324/500
# Saving frame 325/500
# Saving frame 326/500
# Saving frame 327/500
# Saving frame 328/500
# Saving frame 329/500
# Saving frame 330/500
# Saving frame 331/500
# Saving frame 332/500
# Saving frame 333/500
# Saving frame 334/500
# Saving frame 335/500
# Saving frame 336/500
# Saving frame 337/500
# Saving frame 338/500
# Saving frame 339/500
# Saving frame 340/500
# Saving frame 341/500
# Saving frame 342/500
# Saving frame 343/500
# Saving frame 344/500
# Saving frame 345/500
# Saving frame 346/500
# Saving frame 347/500
# Saving frame 348/500
# Saving frame 349/500
# Saving frame 350/500
# Saving frame 351/500
# Saving frame 352/500
# Saving frame 353/500
# Saving frame 354/500
# Saving frame 355/500
# Saving frame 356/500
# Saving frame 357/500
# Saving frame 358/500
# Saving frame 359/500
# Saving frame 360/500
# Saving frame 361/500
# Saving frame 362/500
# Saving frame 363/500
# Saving frame 364/500
# Saving frame 365/500
# Saving frame 366/500
# Saving frame 367/500
# Saving frame 368/500
# Saving frame 369/500
# Saving frame 370/500
# Saving frame 371/500
# Saving frame 372/500
# Saving frame 373/500
# Saving frame 374/500
# Saving frame 375/500
# Saving frame 376/500
# Saving frame 377/500
# Saving frame 378/500
# Saving frame 379/500
# Saving frame 380/500
# Saving frame 381/500
# Saving frame 382/500
# Saving frame 383/500
# Saving frame 384/500
# Saving frame 385/500
# Saving frame 386/500
# Saving frame 387/500
# Saving frame 388/500
# Saving frame 389/500
# Saving frame 390/500
# Saving frame 391/500
# Saving frame 392/500
# Saving frame 393/500
# Saving frame 394/500
# Saving frame 395/500
# Saving frame 396/500
# Saving frame 397/500
# Saving frame 398/500
# Saving frame 399/500
# Saving frame 400/500
# Saving frame 401/500
# Saving frame 402/500
# Saving frame 403/500
# Saving frame 404/500
# Saving frame 405/500
# Saving frame 406/500
# Saving frame 407/500
# Saving frame 408/500
# Saving frame 409/500
# Saving frame 410/500
# Saving frame 411/500
# Saving frame 412/500
# Saving frame 413/500
# Saving frame 414/500
# Saving frame 415/500
# Saving frame 416/500
# Saving frame 417/500
# Saving frame 418/500
# Saving frame 419/500
# Saving frame 420/500
# Saving frame 421/500
# Saving frame 422/500
# Saving frame 423/500
# Saving frame 424/500
# Saving frame 425/500
# Saving frame 426/500
# Saving frame 427/500
# Saving frame 428/500
# Saving frame 429/500
# Saving frame 430/500
# Saving frame 431/500
# Saving frame 432/500
# Saving frame 433/500
# Saving frame 434/500
# Saving frame 435/500
# Saving frame 436/500
# Saving frame 437/500
# Saving frame 438/500
# Saving frame 439/500
# Saving frame 440/500
# Saving frame 441/500
# Saving frame 442/500
# Saving frame 443/500
# Saving frame 444/500
# Saving frame 445/500
# Saving frame 446/500
# Saving frame 447/500
# Saving frame 448/500
# Saving frame 449/500
# Saving frame 450/500
# Saving frame 451/500
# Saving frame 452/500
# Saving frame 453/500
# Saving frame 454/500
# Saving frame 455/500
# Saving frame 456/500
# Saving frame 457/500
# Saving frame 458/500
# Saving frame 459/500
# Saving frame 460/500
# Saving frame 461/500
# Saving frame 462/500
# Saving frame 463/500
# Saving frame 464/500
# Saving frame 465/500
# Saving frame 466/500
# Saving frame 467/500
# Saving frame 468/500
# Saving frame 469/500
# Saving frame 470/500
# Saving frame 471/500
# Saving frame 472/500
# Saving frame 473/500
# Saving frame 474/500
# Saving frame 475/500
# Saving frame 476/500
# Saving frame 477/500
# Saving frame 478/500
# Saving frame 479/500
# Saving frame 480/500
# Saving frame 481/500
# Saving frame 482/500
# Saving frame 483/500
# Saving frame 484/500
# Saving frame 485/500
# Saving frame 486/500
# Saving frame 487/500
# Saving frame 488/500
# Saving frame 489/500
# Saving frame 490/500
# Saving frame 491/500
# Saving frame 492/500
# Saving frame 493/500
# Saving frame 494/500
# Saving frame 495/500
# Saving frame 496/500
# Saving frame 497/500
# Saving frame 498/500
# Saving frame 499/500
# Saving frame 500/500
# Successfully created 2004_Indian_ocean.gif

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import glob
import os
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# Parameters
NX, NY = 200, 200
zlim = 10.0
input_dir = "wave_data_india"
output_file = "2004_Indian_ocean_seismic.gif"  
frame_step = 3  # Process every 3th frame for smaller files

# Get sorted list of CSV files
frame_files = sorted(glob.glob(os.path.join(input_dir, "frame_*.csv")))
if not frame_files:
    raise FileNotFoundError(f"No CSV files found in {input_dir}")

# Create figure
fig = plt.figure(figsize=(12, 8), dpi=100)  # Reduced DPI for smaller file
ax = fig.add_subplot(111, projection='3d')

# Kilometer-scale coordinates
x_coords = np.linspace(0, (NX-1)*0.5, NX)  # 500m grid -> km units
y_coords = np.linspace(0, (NY-1)*0.5, NY)
X, Y = np.meshgrid(x_coords, y_coords)

def init():
    ax.clear()
    data = pd.read_csv(frame_files[0], header=None).values
    surf = ax.plot_surface(X, Y, data.T, cmap='seismic', vmin=-zlim, vmax=zlim)
    
    ax.set_xlabel('Distance (km)', fontsize=10)
    ax.set_ylabel('Distance (km)', fontsize=10)
    ax.set_zlabel('Wave Height (m)', fontsize=10)
    ax.set_title('2004 Indian Ocean Tsunami\nSimulation', fontsize=12)
    ax.set_zlim(-zlim, zlim)
    ax.view_init(elev=40, azim=35)  # Better viewing angle
    
    cbar = fig.colorbar(surf, shrink=0.6)
    cbar.set_label('Wave Height (m)')
    
    return [surf]

def update(frame_num):
    ax.clear()
    data = pd.read_csv(frame_files[frame_num*frame_step], header=None).values
    
    surf = ax.plot_surface(X, Y, data.T, cmap='seismic', 
                         vmin=-zlim, vmax=zlim,
                         rstride=2, cstride=2)  # Reduced density
    
    time_min = (frame_num * frame_step * 0.5) / 60  # Convert to minutes
    ax.set_title(f'Indian Ocean Tsunami @ {time_min:.1f} min', fontsize=12)
    
    # Maintain consistent styling
    ax.set_xlabel('Distance (km)', fontsize=10)
    ax.set_ylabel('Distance (km)', fontsize=10)
    ax.set_zlabel('Wave Height (m)', fontsize=10)
    ax.set_zlim(-zlim, zlim)
    ax.view_init(elev=40, azim=35)
    
    return [surf]

# Create animation with limited frames
print("Creating optimized animation...")
n_frames = min(500, len(frame_files)//frame_step)  # Max 500 frames
anim = FuncAnimation(fig, update, frames=n_frames,
                    init_func=init, blit=False, interval=100)

# Save with explicit writer settings
writer = 'pillow' if len(frame_files) < 500 else 'imagemagick'
try:
    anim.save(output_file, writer=writer, 
             fps=10, dpi=100, 
             progress_callback=lambda i, n: print(f'Saving frame {i+1}/{n}'))
    print(f"Successfully created {output_file}")
except Exception as e:
    print(f"Error: {str(e)}")
    print("Trying alternative saving method...")
    anim.save(output_file, writer='pillow', fps=8, dpi=80)

plt.close()
# Out:
# Creating optimized animation...
# MovieWriter imagemagick unavailable; using Pillow instead.
# Saving frame 1/500
# Saving frame 2/500
# Saving frame 3/500
# Saving frame 4/500
# Saving frame 5/500
# Saving frame 6/500
# Saving frame 7/500
# Saving frame 8/500
# Saving frame 9/500
# Saving frame 10/500
# Saving frame 11/500
# Saving frame 12/500
# Saving frame 13/500
# Saving frame 14/500
# Saving frame 15/500
# Saving frame 16/500
# Saving frame 17/500
# Saving frame 18/500
# Saving frame 19/500
# Saving frame 20/500
# Saving frame 21/500
# Saving frame 22/500
# Saving frame 23/500
# Saving frame 24/500
# Saving frame 25/500
# Saving frame 26/500
# Saving frame 27/500
# Saving frame 28/500
# Saving frame 29/500
# Saving frame 30/500
# Saving frame 31/500
# Saving frame 32/500
# Saving frame 33/500
# Saving frame 34/500
# Saving frame 35/500
# Saving frame 36/500
# Saving frame 37/500
# Saving frame 38/500
# Saving frame 39/500
# Saving frame 40/500
# Saving frame 41/500
# Saving frame 42/500
# Saving frame 43/500
# Saving frame 44/500
# Saving frame 45/500
# Saving frame 46/500
# Saving frame 47/500
# Saving frame 48/500
# Saving frame 49/500
# Saving frame 50/500
# Saving frame 51/500
# Saving frame 52/500
# Saving frame 53/500
# Saving frame 54/500
# Saving frame 55/500
# Saving frame 56/500
# Saving frame 57/500
# Saving frame 58/500
# Saving frame 59/500
# Saving frame 60/500
# Saving frame 61/500
# Saving frame 62/500
# Saving frame 63/500
# Saving frame 64/500
# Saving frame 65/500
# Saving frame 66/500
# Saving frame 67/500
# Saving frame 68/500
# Saving frame 69/500
# Saving frame 70/500
# Saving frame 71/500
# Saving frame 72/500
# Saving frame 73/500
# Saving frame 74/500
# Saving frame 75/500
# Saving frame 76/500
# Saving frame 77/500
# Saving frame 78/500
# Saving frame 79/500
# Saving frame 80/500
# Saving frame 81/500
# Saving frame 82/500
# Saving frame 83/500
# Saving frame 84/500
# Saving frame 85/500
# Saving frame 86/500
# Saving frame 87/500
# Saving frame 88/500
# Saving frame 89/500
# Saving frame 90/500
# Saving frame 91/500
# Saving frame 92/500
# Saving frame 93/500
# Saving frame 94/500
# Saving frame 95/500
# Saving frame 96/500
# Saving frame 97/500
# Saving frame 98/500
# Saving frame 99/500
# Saving frame 100/500
# Saving frame 101/500
# Saving frame 102/500
# Saving frame 103/500
# Saving frame 104/500
# Saving frame 105/500
# Saving frame 106/500
# Saving frame 107/500
# Saving frame 108/500
# Saving frame 109/500
# Saving frame 110/500
# Saving frame 111/500
# Saving frame 112/500
# Saving frame 113/500
# Saving frame 114/500
# Saving frame 115/500
# Saving frame 116/500
# Saving frame 117/500
# Saving frame 118/500
# Saving frame 119/500
# Saving frame 120/500
# Saving frame 121/500
# Saving frame 122/500
# Saving frame 123/500
# Saving frame 124/500
# Saving frame 125/500
# Saving frame 126/500
# Saving frame 127/500
# Saving frame 128/500
# Saving frame 129/500
# Saving frame 130/500
# Saving frame 131/500
# Saving frame 132/500
# Saving frame 133/500
# Saving frame 134/500
# Saving frame 135/500
# Saving frame 136/500
# Saving frame 137/500
# Saving frame 138/500
# Saving frame 139/500
# Saving frame 140/500
# Saving frame 141/500
# Saving frame 142/500
# Saving frame 143/500
# Saving frame 144/500
# Saving frame 145/500
# Saving frame 146/500
# Saving frame 147/500
# Saving frame 148/500
# Saving frame 149/500
# Saving frame 150/500
# Saving frame 151/500
# Saving frame 152/500
# Saving frame 153/500
# Saving frame 154/500
# Saving frame 155/500
# Saving frame 156/500
# Saving frame 157/500
# Saving frame 158/500
# Saving frame 159/500
# Saving frame 160/500
# Saving frame 161/500
# Saving frame 162/500
# Saving frame 163/500
# Saving frame 164/500
# Saving frame 165/500
# Saving frame 166/500
# Saving frame 167/500
# Saving frame 168/500
# Saving frame 169/500
# Saving frame 170/500
# Saving frame 171/500
# Saving frame 172/500
# Saving frame 173/500
# Saving frame 174/500
# Saving frame 175/500
# Saving frame 176/500
# Saving frame 177/500
# Saving frame 178/500
# Saving frame 179/500
# Saving frame 180/500
# Saving frame 181/500
# Saving frame 182/500
# Saving frame 183/500
# Saving frame 184/500
# Saving frame 185/500
# Saving frame 186/500
# Saving frame 187/500
# Saving frame 188/500
# Saving frame 189/500
# Saving frame 190/500
# Saving frame 191/500
# Saving frame 192/500
# Saving frame 193/500
# Saving frame 194/500
# Saving frame 195/500
# Saving frame 196/500
# Saving frame 197/500
# Saving frame 198/500
# Saving frame 199/500
# Saving frame 200/500
# Saving frame 201/500
# Saving frame 202/500
# Saving frame 203/500
# Saving frame 204/500
# Saving frame 205/500
# Saving frame 206/500
# Saving frame 207/500
# Saving frame 208/500
# Saving frame 209/500
# Saving frame 210/500
# Saving frame 211/500
# Saving frame 212/500
# Saving frame 213/500
# Saving frame 214/500
# Saving frame 215/500
# Saving frame 216/500
# Saving frame 217/500
# Saving frame 218/500
# Saving frame 219/500
# Saving frame 220/500
# Saving frame 221/500
# Saving frame 222/500
# Saving frame 223/500
# Saving frame 224/500
# Saving frame 225/500
# Saving frame 226/500
# Saving frame 227/500
# Saving frame 228/500
# Saving frame 229/500
# Saving frame 230/500
# Saving frame 231/500
# Saving frame 232/500
# Saving frame 233/500
# Saving frame 234/500
# Saving frame 235/500
# Saving frame 236/500
# Saving frame 237/500
# Saving frame 238/500
# Saving frame 239/500
# Saving frame 240/500
# Saving frame 241/500
# Saving frame 242/500
# Saving frame 243/500
# Saving frame 244/500
# Saving frame 245/500
# Saving frame 246/500
# Saving frame 247/500
# Saving frame 248/500
# Saving frame 249/500
# Saving frame 250/500
# Saving frame 251/500
# Saving frame 252/500
# Saving frame 253/500
# Saving frame 254/500
# Saving frame 255/500
# Saving frame 256/500
# Saving frame 257/500
# Saving frame 258/500
# Saving frame 259/500
# Saving frame 260/500
# Saving frame 261/500
# Saving frame 262/500
# Saving frame 263/500
# Saving frame 264/500
# Saving frame 265/500
# Saving frame 266/500
# Saving frame 267/500
# Saving frame 268/500
# Saving frame 269/500
# Saving frame 270/500
# Saving frame 271/500
# Saving frame 272/500
# Saving frame 273/500
# Saving frame 274/500
# Saving frame 275/500
# Saving frame 276/500
# Saving frame 277/500
# Saving frame 278/500
# Saving frame 279/500
# Saving frame 280/500
# Saving frame 281/500
# Saving frame 282/500
# Saving frame 283/500
# Saving frame 284/500
# Saving frame 285/500
# Saving frame 286/500
# Saving frame 287/500
# Saving frame 288/500
# Saving frame 289/500
# Saving frame 290/500
# Saving frame 291/500
# Saving frame 292/500
# Saving frame 293/500
# Saving frame 294/500
# Saving frame 295/500
# Saving frame 296/500
# Saving frame 297/500
# Saving frame 298/500
# Saving frame 299/500
# Saving frame 300/500
# Saving frame 301/500
# Saving frame 302/500
# Saving frame 303/500
# Saving frame 304/500
# Saving frame 305/500
# Saving frame 306/500
# Saving frame 307/500
# Saving frame 308/500
# Saving frame 309/500
# Saving frame 310/500
# Saving frame 311/500
# Saving frame 312/500
# Saving frame 313/500
# Saving frame 314/500
# Saving frame 315/500
# Saving frame 316/500
# Saving frame 317/500
# Saving frame 318/500
# Saving frame 319/500
# Saving frame 320/500
# Saving frame 321/500
# Saving frame 322/500
# Saving frame 323/500
# Saving frame 324/500
# Saving frame 325/500
# Saving frame 326/500
# Saving frame 327/500
# Saving frame 328/500
# Saving frame 329/500
# Saving frame 330/500
# Saving frame 331/500
# Saving frame 332/500
# Saving frame 333/500
# Saving frame 334/500
# Saving frame 335/500
# Saving frame 336/500
# Saving frame 337/500
# Saving frame 338/500
# Saving frame 339/500
# Saving frame 340/500
# Saving frame 341/500
# Saving frame 342/500
# Saving frame 343/500
# Saving frame 344/500
# Saving frame 345/500
# Saving frame 346/500
# Saving frame 347/500
# Saving frame 348/500
# Saving frame 349/500
# Saving frame 350/500
# Saving frame 351/500
# Saving frame 352/500
# Saving frame 353/500
# Saving frame 354/500
# Saving frame 355/500
# Saving frame 356/500
# Saving frame 357/500
# Saving frame 358/500
# Saving frame 359/500
# Saving frame 360/500
# Saving frame 361/500
# Saving frame 362/500
# Saving frame 363/500
# Saving frame 364/500
# Saving frame 365/500
# Saving frame 366/500
# Saving frame 367/500
# Saving frame 368/500
# Saving frame 369/500
# Saving frame 370/500
# Saving frame 371/500
# Saving frame 372/500
# Saving frame 373/500
# Saving frame 374/500
# Saving frame 375/500
# Saving frame 376/500
# Saving frame 377/500
# Saving frame 378/500
# Saving frame 379/500
# Saving frame 380/500
# Saving frame 381/500
# Saving frame 382/500
# Saving frame 383/500
# Saving frame 384/500
# Saving frame 385/500
# Saving frame 386/500
# Saving frame 387/500
# Saving frame 388/500
# Saving frame 389/500
# Saving frame 390/500
# Saving frame 391/500
# Saving frame 392/500
# Saving frame 393/500
# Saving frame 394/500
# Saving frame 395/500
# Saving frame 396/500
# Saving frame 397/500
# Saving frame 398/500
# Saving frame 399/500
# Saving frame 400/500
# Saving frame 401/500
# Saving frame 402/500
# Saving frame 403/500
# Saving frame 404/500
# Saving frame 405/500
# Saving frame 406/500
# Saving frame 407/500
# Saving frame 408/500
# Saving frame 409/500
# Saving frame 410/500
# Saving frame 411/500
# Saving frame 412/500
# Saving frame 413/500
# Saving frame 414/500
# Saving frame 415/500
# Saving frame 416/500
# Saving frame 417/500
# Saving frame 418/500
# Saving frame 419/500
# Saving frame 420/500
# Saving frame 421/500
# Saving frame 422/500
# Saving frame 423/500
# Saving frame 424/500
# Saving frame 425/500
# Saving frame 426/500
# Saving frame 427/500
# Saving frame 428/500
# Saving frame 429/500
# Saving frame 430/500
# Saving frame 431/500
# Saving frame 432/500
# Saving frame 433/500
# Saving frame 434/500
# Saving frame 435/500
# Saving frame 436/500
# Saving frame 437/500
# Saving frame 438/500
# Saving frame 439/500
# Saving frame 440/500
# Saving frame 441/500
# Saving frame 442/500
# Saving frame 443/500
# Saving frame 444/500
# Saving frame 445/500
# Saving frame 446/500
# Saving frame 447/500
# Saving frame 448/500
# Saving frame 449/500
# Saving frame 450/500
# Saving frame 451/500
# Saving frame 452/500
# Saving frame 453/500
# Saving frame 454/500
# Saving frame 455/500
# Saving frame 456/500
# Saving frame 457/500
# Saving frame 458/500
# Saving frame 459/500
# Saving frame 460/500
# Saving frame 461/500
# Saving frame 462/500
# Saving frame 463/500
# Saving frame 464/500
# Saving frame 465/500
# Saving frame 466/500
# Saving frame 467/500
# Saving frame 468/500
# Saving frame 469/500
# Saving frame 470/500
# Saving frame 471/500
# Saving frame 472/500
# Saving frame 473/500
# Saving frame 474/500
# Saving frame 475/500
# Saving frame 476/500
# Saving frame 477/500
# Saving frame 478/500
# Saving frame 479/500
# Saving frame 480/500
# Saving frame 481/500
# Saving frame 482/500
# Saving frame 483/500
# Saving frame 484/500
# Saving frame 485/500
# Saving frame 486/500
# Saving frame 487/500
# Saving frame 488/500
# Saving frame 489/500
# Saving frame 490/500
# Saving frame 491/500
# Saving frame 492/500
# Saving frame 493/500
# Saving frame 494/500
# Saving frame 495/500
# Saving frame 496/500
# Saving frame 497/500
# Saving frame 498/500
# Saving frame 499/500
# Saving frame 500/500
# Successfully created 2004_Indian_ocean_seismic.gif
